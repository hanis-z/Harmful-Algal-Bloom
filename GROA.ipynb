# %% [markdown]
# ### Looking at Global Reforestation Opportunity Assessment (GROA) data

# %%
import pandas as pd

# %%
df = pd.read_csv('./data/biomass_litter_CWD.csv',encoding='latin-1')

df.head()
# Out:
#    measurement.id  plot.id  site.id  study.id sites.sitename refor.type  \
# 0             561     8878        7      1097       Cajueiro        SNR
# 1             562     8879        7      1097       Cajueiro        SNR
# 2             563     8880        7      1097       Cajueiro        SNR
# 3             564     8881        7      1097       Cajueiro        SNR
# 4             565     8882        7      1097       Cajueiro        SNR
#
#   species prior prior.disturbance.notes  stand.age  ...    mean_ha  covar_1  \
# 0     NaN    PA                     NaN       15.0  ...  41.362146  min_dbh
# 1     NaN    PA                     NaN       15.0  ...  32.587298  min_dbh
# 2     NaN    PA                     NaN       20.0  ...  42.463184  min_dbh
# 3     NaN    PA                     NaN       20.0  ...  58.631269  min_dbh
# 4     NaN    PA                     NaN       27.0  ...  50.164171  min_dbh
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11105 entries, 0 to 11104
# Data columns (total 25 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   measurement.id           11105 non-null  int64
#  1   plot.id                  11105 non-null  int64
#  2   site.id                  11105 non-null  int64
#  3   study.id                 11105 non-null  int64
#  4   sites.sitename           11105 non-null  object
#  5   refor.type               11105 non-null  object
#  6   species                  6676 non-null   object
#  7   prior                    4493 non-null   object
#  8   prior.disturbance.notes  3463 non-null   object
#  9   stand.age                11105 non-null  float64
#  10  date                     2954 non-null   float64
#  11  n                        11060 non-null  float64
#  12  sub_n                    1319 non-null   float64
#  13  plot.size                10806 non-null  float64
# ...

# %%
len(df['site.id'].unique())
# Out:
# 2226
